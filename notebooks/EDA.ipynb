# %%
import pandas as pd 
import numpy as np 

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
from datetime import datetime, timedelta
from math import ceil
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import matplotlib.dates as mdates
from mplfinance.original_flavor import candlestick_ohlc

from dateutil import parser
from dateutil import relativedelta

import plotly.graph_objects as go

# %%
#! pip install --upgrade mplfinance
#! pip install -U kaleido

# %%
df_adj_close = pd.read_csv(r'../data/adj_close.csv')
df_close = pd.read_csv(r'../data/close.csv')
df_high = pd.read_csv(r'../data/high.csv')
df_low = pd.read_csv(r'../data/low.csv')
df_open = pd.read_csv(r'../data/open.csv')
df_volume = pd.read_csv(r'../data/volume.csv')

# %%
df = pd.melt(df_adj_close, id_vars=['Date'], var_name="Cryptocurrency", 
                    value_name='Value')
df.rename(columns={"Value" : 'adj_close'},inplace = True)

# %%
data =[df_adj_close,df_close, df_high, df_low, df_open,df_volume]
columns = ['close', 'high', 'low', 'open', 'volume']

# %%
for i in data:
    for v in columns: 
        df[v] = pd.melt(i, id_vars=['Date'], var_name="Cryptocurrency", 
                    value_name='Value')['Value']
        df.rename(columns={"Value" : v},inplace = True)

# %%
#df.to_csv(r'../data/DFconcat.csv')

# %% [markdown]
# ## Analysis

# %% [markdown]
# Source Code: https://towardsdatascience.com/cryptocurrency-analysis-with-python-buy-and-hold-c3b0bc164ffa

# %%
df_close['Date']= pd.to_datetime(df_close['Date'])

df['Date']= pd.to_datetime(df['Date'])

# %%
cryptocurrencies = ['ADA-USD', 'ATOM-USD', 'AVAX-USD', 'AXS-USD', 'BTC-USD',
       'ETH-USD', 'LINK-USD', 'LUNA1-USD', 'MATIC-USD', 'SOL-USD']

# %%
#The maximum price each crypto reached of the higher prices 

df_sorted= df_high[cryptocurrencies].max().sort_values()

# function to add value labels
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], round(df_sorted[i],3), ha = 'center')

fig = plt.figure(figsize = (20, 8))
 
# creating the bar plot
plt.bar(df_sorted.index, np.log(df_sorted), color ='maroon',
        width = 0.6)
 
plt.xlabel("Cryptocurrencies")
plt.ylabel("Price")
plt.title("Logarithm of the Higher Prices by Cryptocurrency ")

addlabels(df_sorted.index, np.log(df_sorted))

plt.savefig('log_higher_prices', dpi='figure')
       
plt.show()

# %%
# The higher price of each crypto at closing

df_sorted= df_close[cryptocurrencies].max().sort_values()

# function to add value labels
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], round(df_sorted[i],3), ha = 'center')

fig = plt.figure(figsize = (20, 8))
 
# creating the bar plot
plt.bar(df_sorted.index, np.log(df_sorted), color ='maroon',
        width = 0.6)
 
plt.xlabel("Cryptocurrencies")
plt.ylabel("Price")
plt.title("Logarithm of the Higher Prices by Cryptocurrency ")

addlabels(df_sorted.index, np.log(df_sorted))

plt.savefig('log_higher_close_prices', dpi='figure')

plt.show()

# %%
gold = ['BTC-USD','ETH-USD']
silver = ['ATOM-USD', 'AVAX-USD', 'AXS-USD', 'LINK-USD', 'LUNA1-USD','SOL-USD']
bronze = ['MATIC-USD','ADA-USD']

# %%
df_sol = pd.read_csv(r'../data/cryptoInd/sol_ind.csv')

# %%
df_sol
# Out:
#            Date   adj_close       close         low        high        open  \
# 0    2020-05-13    0.550532    0.550532    0.518038    0.564874    0.538372
# 1    2020-05-14    0.569118    0.569118    0.550110    0.580946    0.550532
# 2    2020-05-15    0.559752    0.559752    0.547093    0.574620    0.569193
# 3    2020-05-18    0.652670    0.652670    0.609649    0.674393    0.612682
# 4    2020-05-19    0.624454    0.624454    0.611248    0.654480    0.650974
# ..          ...         ...         ...         ...         ...         ...
# 487  2022-04-19  108.582031  108.582031  101.301727  108.582031  102.202385
# 488  2022-04-20  105.497002  105.497002  104.772659  110.722977  108.602196
# 489  2022-04-21  101.776138  101.776138  100.767151  109.765327  105.497673
# 490  2022-04-22  100.612053  100.612053   99.579430  103.498146  101.757423
# 491  2022-04-25  101.247635  101.247635   94.755753  101.440590   99.241409
#
#            volume       SMA30      CMA30       EMA30  ...     bb_high  \
# 0    2.326446e+06    0.630456   0.658397    0.603585  ...    0.773171
# 1    2.047897e+06    0.618675   0.655847    0.599277  ...    0.750072
# 2    1.850070e+06    0.609922   0.653177    0.594336  ...    0.738327
# 3    3.314359e+06    0.592627   0.650748    0.604126  ...    0.680708
# 4    2.380263e+06    0.589758   0.650090    0.606667  ...    0.670386
# ..            ...         ...        ...         ...  ...         ...
# 487  1.711910e+09  107.742056  56.135475  106.692858  ...  122.940242
# 488  1.761532e+09  106.317707  56.202090  106.543376  ...  117.574949
# 489  1.838572e+09  105.577224  56.263510  105.947471  ...  116.464692
# 490  1.274794e+09  104.364927  56.323199  105.280544  ...  112.887396
# 491  1.538487e+09  102.145710  56.500488  103.681166  ...  107.032667
#
#          macd  macdsignal  macdhist        rsi     stdev      slowk  \
# 0   -0.041228   -0.028529 -0.012699  36.035358  0.071357  23.592362
# 1   -0.039807   -0.030785 -0.009022  38.130968  0.065699  40.929769
# 2   -0.038987   -0.032425 -0.006561  37.468194  0.064203  56.470298
# 3   -0.022666   -0.030375  0.007709  47.820515  0.044041  84.447855
# 4   -0.018956   -0.028092  0.009135  45.216883  0.040314  73.811425
# ..        ...         ...       ...        ...       ...        ...
# 487 -0.750396    0.956023 -1.706418  51.698578  7.599093  57.165963
# 488 -0.738744    0.617069 -1.355814  49.144510  5.628621  74.486018
# 489 -1.018018    0.290052 -1.308070  46.195342  5.443734  69.481850
# 490 -1.318082   -0.031575 -1.286507  45.284427  4.261235  47.710119
# 491 -1.822995   -0.863446 -0.959549  46.305637  2.443478  21.164290
#
#          slowd  dollar_close  sp500_close
# 0    18.768069    100.291000  2820.000000
# 1    26.836762    100.507004  2852.500000
# 2    40.330810    100.433998  2863.699951
# 3    80.017372     99.681000  2953.909912
# 4    79.689734     99.365997  2922.939941
# ..         ...           ...          ...
# 487  38.064413    100.963997  4462.209961
# 488  55.453260    100.417000  4459.450195
# 489  67.044610    100.613998  4393.660156
# 490  63.892662    101.212997  4271.779785
# 491  23.527320    101.768997  4296.120117
#
# [492 rows x 23 columns]

# %%
#Candelstick for SOL-USD

import plotly.io as pio
pio.renderers.default = "notebook_connected"

fig = go.Figure(data=[go.Candlestick(x=df_sol['Date'],
                open=df_sol['open'],
                high=df_sol['high'],
                low=df_sol['low'],
                close=df_sol['close'])])
fig.write_image("candelstick.png")
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="0d9eaa93-f3ee-4482-af16-890abaf1fc82" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d9eaa93-f3ee-4482-af16-890abaf1fc82")) {                    Plotly.newPlot(                        "0d9eaa93-f3ee-4482-af16-890abaf1fc82",                        [{"close":[0.5505319833755493,0.5691180229187012,0.5597519874572754,0.6526700258255005,0.6244540214538574,0.5791559815406799,0.6089149713516235,0.6388750076293945,0.5733069777488708,0.5909850001335144,0.5751550197601318,0.5794150233268738,0.5774949789047241,0.5646690130233765,0.5866209864616394,0.5872989892959595,0.6611549854278564,0.6683130264282227,0.6580020189285278,0.6448670029640198,0.5737419724464417,0.5938689708709717,0.5706390142440796,0.5855759978294373,0.5815619826316833,0.6209560036659241,0.684332013130188,0.7268480062484741,0.7082970142364502,0.7369940280914307,0.7131940126419067,0.7411440014839172,0.8524540066719055,0.8600940108299255,0.8326420187950134,0.7802190184593201,0.7079079747200012,0.7530480027198792,0.7967129945755005,0.8534529805183411,0.9135599732398988,1.175734043121338,1.148074984550476,1.289597988128662,0.8724409937858582,0.9778370261192322,0.8730890154838562,0.9771659970283508,1.044087052345276,1.0498440265655518,0.9953460097312928,1.7786359786987305,1.7840670347213743,1.6582889556884766,1.6868070363998413,1.5381779670715332,1.802610993385315,1.8716390132904053,1.7545499801635742,2.206347942352295,2.0859029293060303,3.1317930221557617,3.30341911315918,3.769751071929932,3.75597095489502,3.4093880653381348,3.098608016967773,3.3299760818481445,2.899040937423706,3.2082669734954834,2.9436678886413574,3.3449859619140625,3.264849901199341,3.5583748817443848,3.4450600147247314,4.011393070220947,4.782045841217041,4.344515800476074,4.1644721031188965,3.5273399353027344,3.545794010162353,2.4689769744873047,3.636378049850464,3.469836950302124,3.4274280071258545,3.2691330909729004,2.9391210079193115,2.5453989505767822,2.891874074935913,3.107939958572388,2.782509088516236,2.9155189990997314,2.836756944656372,3.1327149868011475,3.1886119842529297,2.9566779136657715,2.9464330673217773,2.897876024246216,2.861027956008911,2.62608289718628,2.657644033432007,2.1762499809265137,2.2917959690093994,2.365220069885254,2.5398590564727783,2.587071895599365,2.404910087585449,2.3146350383758545,2.2664361000061035,2.149385929107666,2.058079957962036,1.8886719942092896,1.8903779983520508,1.9556529521942136,1.960034966468811,1.6854660511016846,1.7102320194244385,1.4900530576705933,1.428936004638672,1.4413360357284546,1.474071979522705,1.4122339487075806,1.3922549486160278,1.4052180051803589,1.9137400388717647,2.0286519527435303,2.247987031936645,2.002125024795532,1.8991379737854004,2.020792007446289,2.255354881286621,2.202181100845337,2.1150290966033936,2.0767691135406494,2.0953919887542725,2.276376962661743,2.267966985702514,2.270034074783325,1.8579490184783936,1.966891050338745,1.976307988166809,2.115401029586792,2.1003708839416504,1.8559529781341555,1.8311729431152344,1.6653519868850708,1.6623040437698364,1.5741510391235352,1.4445849657058716,1.5916459560394287,1.7606710195541382,1.7835979461669922,1.6786340475082395,1.698799967765808,1.5419150590896606,1.4902859926223757,1.2056920528411863,1.3624080419540403,1.515684962272644,1.6743450164794922,1.5354570150375366,1.5108979940414429,2.4850969314575195,2.157217025756836,1.929216980934143,2.3727450370788574,3.219887018203736,3.1080899238586426,3.61339807510376,3.513782024383545,3.2781639099121094,3.2501609325408936,3.641865968704224,3.723577976226807,2.9905359745025635,3.346229076385498,3.699980974197388,4.04734992980957,3.690587043762207,3.8220720291137695,3.8346760272979736,4.611601829528809,5.267508029937744,5.71599006652832,6.426064968109131,6.68171977996 ...

# %%
df_high.describe()
# Out:
#            ADA-USD     ATOM-USD    AVAX-USD     AXS-USD       BTC-USD  \
# count  1629.000000  1139.000000  583.000000  538.000000   1826.000000
# mean      0.517245    12.778245   45.504667   46.068519  18504.529287
# std       0.696980    11.856017   36.919261   47.519941  18123.144096
# min       0.025993     1.813534    2.939915    0.149547   1294.829956
# 25%       0.056926     3.964141   12.434371    4.056442   6601.734985
# 50%       0.125663     5.646225   34.697552   44.936834   9460.083984
# 75%       0.956904    22.361992   78.041763   73.827532  33931.668945
# max       3.099186    44.695526  146.217865  165.369080  68789.625000
#
#            ETH-USD     LINK-USD    LUNA1-USD    MATIC-USD     SOL-USD
# count  1629.000000  1629.000000  1005.000000  1094.000000  746.000000
# mean   1102.866267     9.718100    18.761969     0.574255   59.203741
# std    1293.636227    11.654902    29.721443     0.787871   71.855456
# min      85.342743     0.166283     0.137031     0.003380    0.559759
# 25%     203.500549     0.515894     0.312570     0.017333    2.252829
# 50%     406.303955     2.874556     1.119922     0.024612   28.238139
# 75%    1843.818848    16.744186    26.812210     1.346856  103.409777
# max    4891.704590    52.876087   119.184624     2.923235  260.062103

# %%
# diference between the max and minimum value for each crypto
df_high.describe().iloc[7] - df_high.describe().iloc[3]
# Out:
# ADA-USD          3.073193
# ATOM-USD        42.881992
# AVAX-USD       143.277950
# AXS-USD        165.219533
# BTC-USD      67494.795044
# ETH-USD       4806.361847
# LINK-USD        52.709804
# LUNA1-USD      119.047593
# MATIC-USD        2.919855
# SOL-USD        259.502344
# dtype: float64

# %%
df_close['Date'].min()
# Out:
# Timestamp('2017-04-26 00:00:00')

# %%
# All Numeric Variables' Box Plots in one figure
sns.set()

# Prepare figure. Create individual axes where each box plot will be placed
fig, axes = plt.subplots(2, ceil(len(cryptocurrencies) / 2), figsize=(20, 11))

# Plot data
# Iterate across axes objects and associate each box plot:
for ax, feat in zip(axes.flatten(),cryptocurrencies): 
    sns.boxplot(x=df_close[feat], ax=ax)
    
# Layout
# Add a centered title to the figure:
title = "Cryptocurrencies' Box Plots"

plt.suptitle(title)
plt.show()

# %%
# All Numeric Variables' Histograms in one figure
sns.set()

# Prepare figure. Create individual axes where each histogram will be placed
fig, axes = plt.subplots(2, ceil(len(cryptocurrencies) / 2), figsize=(20, 11))

# Plot data
# Iterate across axes objects and associate each histogram (hint: use the ax.hist() instead of plt.hist()):
for ax, feat in zip(axes.flatten(), cryptocurrencies): 
    ax.hist(df_close[feat])
    ax.set_title(feat, y=-0.13)
    
# Layout
# Add a centered title to the figure:
title = "Cryptocurrencies' Histograms"

plt.suptitle(title)
plt.savefig('cryptocurrencies_histograms', dpi='figure')
plt.show()

# %%
#Histogram for Sol-USD using median

df_high['SOL-USD'].hist(bins=30, figsize=(15,10)).axvline(df_high['SOL-USD'].median(), color='b', linestyle='dashed', linewidth=2)

plt.savefig('histogram sol', dpi='figure')
print(df_high['SOL-USD'].median())
# Out:
# 28.238139152526855

# %% [markdown]
# Observations:
# - SOL-USD closing price was not over $50 for many hours.
# - it has right-skewed distribution because a natural limit prevents outcomes on one side.
# - blue dashed line (median) shows that half of the time closing prices were under $28.24.

# %% [markdown]
# #### Visualize absolute closing prices

# %%
df_close.plot(grid=True, figsize=(15, 10))
plt.savefig('absolute_closing ', dpi='figure')

# %% [markdown]
# #### Visualize relative changes in closing prices

# %%
fig, ax1 = plt.subplots(figsize=(20, 10))
ax2 = ax1.twinx()
rspine = ax2.spines['right']
rspine.set_position(('axes', 1.15))
ax2.set_frame_on(True)
ax2.patch.set_visible(False)
fig.subplots_adjust(right=0.7)
df_close['BTC-USD'].plot(ax=ax1, style='b-')
df_close['ETH-USD'].plot(ax=ax1, style='r-', secondary_y=True)
df_close['SOL-USD'].plot(ax=ax2, style='g-')
# legend
ax2.legend([ax1.get_lines()[0],
            ax1.right_ax.get_lines()[0],
            ax2.get_lines()[0]],
           ['BTC-USD', 'ETH-USD', 'SOL-USD'])

plt.savefig('relative_closing ', dpi='figure')

# %% [markdown]
# We are interested in a relative change of the price rather than in absolute price, so we use three different y-axis scales.
#
# We see that closing prices move in tandem. When one coin closing price increases so do the other.

# %% [markdown]
# ### Measure the correlation of closing prices

# %%
# Compute the correlation matrix
corr = df_close.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 10))
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, annot=True, fmt = '.4f', mask=mask, center=0, square=True, linewidths=.5)

plt.savefig('corr_heatmap ', dpi='figure')

# %% [markdown]
# ### Log Returns

# %%
# shift moves dates back by 1
df_log = df_close.set_index('Date').apply(lambda x: np.log(x) - np.log(x.shift(1)))

# %%
df_sample = df_log.copy()

# %%
df_sample[gold]
# Out:
#              BTC-USD   ETH-USD
# Date
# 2017-04-26       NaN       NaN
# 2017-04-27  0.028207       NaN
# 2017-04-28 -0.000949       NaN
# 2017-04-29  0.004025       NaN
# 2017-04-30  0.019554       NaN
# ...              ...       ...
# 2022-04-21 -0.020684 -0.029767
# 2022-04-22 -0.019611 -0.007609
# 2022-04-23 -0.006402 -0.009054
# 2022-04-24 -0.000442 -0.005249
# 2022-04-25  0.024749  0.029220
#
# [1826 rows x 2 columns]

# %% [markdown]
# Visualize Log Returns

# %%
# We plot normalized changes of closing prices for last 300 days
# Log differences can be interpreted as the percentage change.
df_sample[:300].plot(figsize=(15, 10)).axhline(color='black', linewidth=2)
plt.savefig('normalized_closing', dpi='figure')

# %%
# We plot normalized changes of closing prices for last 500 days
# Log differences can be interpreted as the percentage change.
df_sample[gold][:500].plot(figsize=(15, 10)).axhline(color='black', linewidth=2)
plt.savefig('normalized_closing_gold', dpi='figure')

# %%
df_sample[silver].plot(figsize=(15, 10)).axhline(color='black', linewidth=2)
plt.savefig('normalized_closing_silver', dpi='figure')

# %%
df_sample[bronze][:1000].plot(figsize=(15, 10)).axhline(color='black', linewidth=2)
plt.savefig('normalized_closing_bronze', dpi='figure')

# %%
# Compute the correlation matrix
corr = df_log.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 10))
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, annot=True, fmt = '.4f', mask=mask, center=0, square=True, linewidths=.5)

plt.savefig('corr_heatmap_log', dpi='figure')
